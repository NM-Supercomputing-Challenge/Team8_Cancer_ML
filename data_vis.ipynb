# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("D:\Cancer_Project\Team8_Cancer_ML\HNSCC\HNSCC Clinical Data (Encoded).csv")

# %%
df.head()
# Out:
#    Unnamed: 0  TCIA code    Gender  Age at Diag  Smoking status  \
# 0           0   0.727884  0.779711           57        0.671171
# 1           1   0.727884  0.779711           48        0.781011
# 2           2   0.727884  0.779711           54        0.671171
# 3           3   0.727884  0.701011           55        0.781011
# 4           4   0.727884  0.779711           66        0.701111
#
#    Smoking status (Packs-Years)  Tumor laterality  Cancer subsite of origin  \
# 0                          38.0              0.82                  0.669712
# 1                           0.0              0.82                  0.669712
# 2                          30.0              0.82                  0.841111
# 3                           0.0              0.76                  0.841111
# 4                          25.0              0.76                  0.669712
#
#    HPV Status  T-category  ...  Local control_duration  Regional control  \
# 0    0.851101           4  ...                     223          0.891011
# 1    0.851101           1  ...                     924          0.891011
# 2    0.851101           2  ...                    3770          0.781110
# 3    0.851101           2  ...                    4104          0.891011
# 4    0.851101           4  ...                    3496          0.891011
#
#    Regional control_duration  Locoregional control  \
# 0                        223              0.891011
# 1                        924              0.891011
# 2                       3770              0.781110
# 3                       4104              0.891011
# 4                       3496              0.891011
#
#    Locoregional control_duration  Freedom from distant metastasis  \
# 0                            223                         0.891011
# 1                            924                         0.891011
# 2                           3770                         0.891011
# 3                           4104                         0.891011
# 4                           3496                         0.891011
#
#    Freedom from distant metastasis_duration  Relapse-free survival  \
# 0                                       7.3               0.891011
# 1                                      30.4               0.891011
# 2                                     123.9               0.781110
# 3                                     135.0               0.891011
# 4                                     114.8               0.891011
#
#    Days to last FU  Neck Dissection after IMRT
# 0              220                    0.781110
# 1              913                    0.781110
# 2             3717                    0.891011
# 3             4049                    0.781110
# 4             3445                    0.781110
#
# [5 rows x 30 columns]

# %%
corr = df.corr()
print(corr.head())
# Out:
#                   Unnamed: 0     TCIA code        Gender   Age at Diag  \
# Unnamed: 0      1.000000e+00  5.751456e-15 -1.041349e-01  1.093144e-01
# TCIA code       5.751456e-15  1.000000e+00 -1.984353e-13 -4.722220e-16
# Gender         -1.041349e-01 -1.984353e-13  1.000000e+00 -2.596240e-02
# Age at Diag     1.093144e-01 -4.722220e-16 -2.596240e-02  1.000000e+00
# Smoking status -2.234079e-02 -3.477574e-14 -1.585922e-02 -6.642608e-02
#
#                 Smoking status  Smoking status (Packs-Years)  \
# Unnamed: 0       -2.234079e-02                 -7.674735e-02
# TCIA code        -3.477574e-14                 -3.926017e-16
# Gender           -1.585922e-02                 -1.971370e-02
# Age at Diag      -6.642608e-02                  2.060759e-01
# Smoking status    1.000000e+00                 -5.691508e-01
#
#                 Tumor laterality  Cancer subsite of origin    HPV Status  \
# Unnamed: 0         -3.607565e-03              3.784255e-02 -5.983058e-01
# TCIA code           1.874868e-13             -5.443588e-14 -1.191664e-13
# Gender             -7.626688e-02             -9.185802e-02  1.248023e-01
# Age at Diag         1.071889e-02             -6.192854e-02 -6.450900e-02
# Smoking status      7.902846e-02             -8.397250e-02  1.207309e-01
#
#                   T-category  ...  Local control_duration  Regional control  \
# Unnamed: 0     -1.023842e-01  ...           -4.088061e-01      2.524496e-02
# TCIA code       5.145862e-16  ...            7.160618e-16      6.667420e-14
# Gender         -5.999944e-02  ...           -4.033614e-02      9.464862e-03
# Age at Diag     8.430756e-02  ...           -9.191725e-02     -7.249839e-02
# Smoking status -8.672367e-02  ...            1.174223e-01      3.673812e-02
#
#                 Regional control_duration  Locoregional control  \
# Unnamed: 0                  -4.088061e-01          8.174541e-02
# TCIA code                    7.160618e-16          3.420656e-14
# Gender                      -4.033614e-02          3.791354e-02
# Age at Diag                 -9.191725e-02         -4.635880e-02
# Smoking status               1.174223e-01          1.043431e-01
#
#                 Locoregional control_duration  \
# Unnamed: 0                      -4.088061e-01
# TCIA code                        7.160618e-16
# Gender                          -4.033614e-02
# Age at Diag                     -9.191725e-02
# Smoking status                   1.174223e-01
#
#                 Freedom from distant metastasis  \
# Unnamed: 0                         5.207390e-02
# TCIA code                          5.634763e-14
# Gender                            -6.018220e-02
# Age at Diag                       -6.810701e-02
# Smoking status                     5.234770e-02
#
#                 Freedom from distant metastasis_duration  \
# Unnamed: 0                                 -3.880008e-01
# TCIA code                                  -3.014706e-15
# Gender                                     -4.614169e-02
# Age at Diag                                -9.298253e-02
# Smoking status                              1.210415e-01
#
#                 Relapse-free survival  Days to last FU  \
# Unnamed: 0               1.610792e-01    -4.087608e-01
# TCIA code                1.370586e-14     7.639979e-16
# Gender                  -3.109276e-02    -4.036575e-02
# Age at Diag             -8.612873e-02    -9.225005e-02
# Smoking status           1.130178e-01     1.173437e-01
#
#                 Neck Dissection after IMRT
# Unnamed: 0                   -1.846098e-01
# TCIA code                    -1.353702e-13
# Gender                        4.861331e-02
# Age at Diag                  -2.247458e-02
# Smoking status               -1.343481e-02
#
# [5 rows x 30 columns]

# %%
plt.pcolor(corr)
plt.yticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns,rotation='vertical')
plt.margins(0.2)
plt.title("Correlation Graph of HNSCC Dataset")
plt.show()

# %%
df=pd.read_csv("D:\Cancer_Project\Cancer Model Performance Data - Prediction (HNSCC-HN1)(CNN).csv")

# %%
df.head()
# Out:
#    Prediction  Rounded Pred  Y test
# 0    0.147991             0    0.11
# 1    0.144592             0    0.11
# 2    0.125825             0    0.11
# 3    0.114453             0    0.11
# 4    0.153853             0    0.11

# %%
x=df['Y test']
y=df['Prediction']

# %%
plt.style.use("ggplot")
plt.plot(x,y)
plt.xlabel("Y test")
plt.ylabel("Prediction ('chemotherapy_given')",fontsize=10)
plt.title("Performance of Model on HNSCC-HN1 Dataset",fontsize=10)
plt.show()

# %%
x=df["Y test"]
y=df['Rounded Pred']

# %%
plt.style.use("ggplot")
plt.plot(x,y)
plt.xlabel("Y test")
plt.ylabel("Rounded Pred ('chemotherapy_given')",fontsize=10)
plt.title("Performance of Model on HNSCC-HN1 Dataset",fontsize=10)
plt.show()
